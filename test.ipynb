# %%
import pandas as pd

df = pd.read_csv('villas.csv')
df.drop([df.columns[0]], axis = 1, inplace=True)

# %%
df.shape
# Out:
# (76, 15)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                                                 Title               Price  \
# 0    Luxurious and Stylish Villa in Gili Air For sale   IDR 3,788,888,888
# 1         New 1 Bedroom Smart Home in Berawa for Sale   IDR 2,572,247,433
# 2   2 Bedroom Modern and Smart Living Townhouse in...   IDR 3,934,025,487
# 3      PEACEFUL AND SCENIC VILLA WITH RICE FIELD VIEW   IDR 2,209,106,619
# 4   Upcoming stylish one bedroom villa for lease i...   IDR 2,708,425,239
# ..                                                ...                 ...
# 71  Beautiful 3 level ocean view villa for sale in...  IDR 11,575,113,451
# 72    Three Bedroom Apartment Inside Five Star Resort   IDR 4,950,000,000
# 73            Brand new leasehold property in Padonan   IDR 3,011,042,584
# 74  Beautiful Tropical Design 2 Bedroom Villa in t...   IDR 5,471,617,358
# 75              Off-Plan Serene Studio Living in Ubud   IDR 1,361,778,053
#
#         Code Location Type of Sale Lease Years  \
# ...
